# %%
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

# %%
def Equilibrio(Equi,Efterma,L,mu,T,kb):
    contador=0 #tiene q volver a cero cuando cambio de potencial
    recuMS=0 #tiene q volver a cero cuando cambio de pontencial
    for i in range (Equi):  
        for j in range (L*L): #montecarlo
            L = Efterma.shape[0] 
            M = L*L 
            dire=np.random.randint(0,2)#0 vertical arriba, 1 horizontal izquierda
            
            
            if dire == 0: #vertical arriba
    
                x = np.random.randint(0,L)
                y = np.random.randint(0,L)
                if (Efterma[x,y] and Efterma[x-1,y]) == 1: #intento des
                    p = np.random.uniform(0,1)
                    Pdes = np.exp(-mu/kb*T)              
                    if p < (Pdes):
                        Efterma[x,y] = 0
                        Efterma[x-1,y] = 0
                
 
                elif (Efterma[x,y] and Efterma[x-1,y]) == 0: #intento ads
                    p = np.random.uniform(0,1)
                    Pads = np.exp(mu/kb*T)
                    if p < (Pads):
                        Efterma[x,y] = 1
                        Efterma[x-1,y] = 1
                
                 
                        
  
                
            else: #dire == 1: #horizontal izquierda
                
                x = np.random.randint(0,L)
                y = np.random.randint(0,L)
                if (Efterma[x,y] and Efterma[x,y-1]) == 1: #intento desorber
                    p = np.random.uniform(0,1)
                    Pdes = np.exp(-mu/kb*T)              
                    if p < (Pdes):
                        Efterma[x,y] = 0
                        Efterma[x,y-1] = 0
                
 
                elif (Efterma[x,y] and Efterma[x,y-1]) == 0: #intento ads
                    p = np.random.uniform(0,1)
                    Pads = np.exp(mu/kb*T)
                    if p < (Pads):
                        Efterma[x,y] = 1
                        Efterma[x,y-1] = 1
            
            
                    
        E_equi=Efterma
               
        N = np.count_nonzero(E_equi) #numero de particulas adsorbidas por cada i
        recuM=N/M #cubrimiento en cada vez q hago montecarlo o sea cada i
        
        if recuM != 0: #si es distinto de cero junta el recuM en recuMS y suma un contador
            recuMS =+ recuM
            contador =+ 1
        else: 
            contador = 1 #si no adsorbe nada pongo contador 1 para q no tire error, de todas maneras
                         #recuMS va a ser cero todavía, entonces recuP va a ser cero
    
    
    recuP=recuMS/contador #hago el promedio de todos los recubrimientos por cada montecarlo
    return recuP,E_equi

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi = 16384
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales=[]
Recubrimiento=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP,E_equi=Equilibrio(Equi,Ei,L,mu,T,kb)
    Ei=E_equi
    Potenciales.append(mu)
    Recubrimiento.append(recuP)
    
    

plt.plot(Potenciales,Recubrimiento, label='16384 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 58min 4s, sys: 18.7 s, total: 58min 23s
# Wall time: 58min 44s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi1 = 8192
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales1=[]
Recubrimiento1=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP1,E_equi1=Equilibrio(Equi1,Ei,L,mu,T,kb)
    Ei=E_equi1
    Potenciales1.append(mu)
    Recubrimiento1.append(recuP1)
    
    

plt.plot(Potenciales1,Recubrimiento1, label='8192 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 29min 3s, sys: 8.7 s, total: 29min 11s
# Wall time: 29min 19s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi2 = 3750
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales2=[]
Recubrimiento2=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP2,E_equi2=Equilibrio(Equi2,Ei,L,mu,T,kb)
    Ei=E_equi2
    Potenciales2.append(mu)
    Recubrimiento2.append(recuP2)
    
    

plt.plot(Potenciales2,Recubrimiento2, label='4096 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 13min 23s, sys: 4.16 s, total: 13min 27s
# Wall time: 13min 32s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi3 = 1875
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales3=[]
Recubrimiento3=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP3,E_equi3=Equilibrio(Equi3,Ei,L,mu,T,kb)
    Ei=E_equi3
    Potenciales3.append(mu)
    Recubrimiento3.append(recuP3)
    
    

plt.plot(Potenciales3,Recubrimiento3, label='2048 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 6min 42s, sys: 2.1 s, total: 6min 45s
# Wall time: 6min 47s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi4 = 1024
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales4=[]
Recubrimiento4=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP4,E_equi4=Equilibrio(Equi4,Ei,L,mu,T,kb)
    Ei=E_equi4
    Potenciales4.append(mu)
    Recubrimiento4.append(recuP4)
    
    

plt.plot(Potenciales4,Recubrimiento4, label='1024 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 3min 39s, sys: 1.13 s, total: 3min 40s
# Wall time: 3min 42s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi5 = 512
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales5=[]
Recubrimiento5=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP5,E_equi5=Equilibrio(Equi5,Ei,L,mu,T,kb)
    Ei=E_equi5
    Potenciales5.append(mu)
    Recubrimiento5.append(recuP5)
    
    

plt.plot(Potenciales5,Recubrimiento5, label='512 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 1min 49s, sys: 616 ms, total: 1min 50s
# Wall time: 1min 51s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi6 = 256
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales6=[]
Recubrimiento6=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP6,E_equi6=Equilibrio(Equi6,Ei,L,mu,T,kb)
    Ei=E_equi6
    Potenciales6.append(mu)
    Recubrimiento6.append(recuP6)
    
    

plt.plot(Potenciales6,Recubrimiento6, label='256 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 55.6 s, sys: 292 ms, total: 55.9 s
# Wall time: 56.2 s

# %%
# %%time
L = 20 #tamaño de la malla LxL
Equi7 = 128
T=1
kb=1
Ei = np.random.randint(0,1,size=[L,L]) #estado incila vacío
Potenciales7=[]
Recubrimiento7=[]
potenciales=np.linspace(-5, 10, 31)

for mu in potenciales:
    recuP7,E_equi7=Equilibrio(Equi7,Ei,L,mu,T,kb)
    Ei=E_equi7
    Potenciales7.append(mu)
    Recubrimiento7.append(recuP7)
    
    

plt.plot(Potenciales7,Recubrimiento7, label='128 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
# Out:
# CPU times: user 27.1 s, sys: 140 ms, total: 27.3 s
# Wall time: 27.4 s

# %%
plt.plot(Potenciales,Recubrimiento, label='16384 pasos de MC')
plt.plot(Potenciales1,Recubrimiento1, label='8192 pasos de MC')
#plt.plot(Potenciales2,Recubrimiento2, label='4096 pasos de MC')
plt.plot(Potenciales3,Recubrimiento3, label='2048 pasos de MC')
#plt.plot(Potenciales4,Recubrimiento4, label='1024 pasos de MC')
#plt.plot(Potenciales5,Recubrimiento5, label='512 pasos de MC')
#plt.plot(Potenciales6,Recubrimiento6, label='256 pasos de MC')
plt.plot(Potenciales7,Recubrimiento7, label='128 pasos de MC')
plt.title('Isoterma de adsorción')
plt.ylabel('Recubrimiento')
plt.xlabel('Potencial químico')
plt.legend()
plt.show()
